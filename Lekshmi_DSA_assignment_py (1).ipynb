# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Iris data set
#Read the dataset to python environment
data = pd.read_excel("/content/iris.xls")

# %%
#Display the columns in the dataset.
data = pd.read_excel("/content/iris.xls")
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#Calculate the mean of each column of the dataset.
print('The mean of the each column in the dataset:\n')
data.mean()
# Out:
# The mean of the each column in the dataset:
# <ipython-input-18-16353c53bb65>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
#Check for the null values present in the dataset.
print('The total number of null values present in each column:\n')
data.isnull().sum()
# Out:
# The total number of null values present in each column:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# VISUALIZATIONS

# %%
plt.bar(data['Classification'],data['PL'],color = 'g', width = 0.4)
plt.title('PETAL LENGTH CLASSIFICATION')
plt.ylabel('PL')
print()

# %% [markdown]
# Bar graph shows how petal length varies among the three species of iris dataset.

# %%
data.hist(edgecolor = 'black', linewidth = 1)
plt.show()

# %%
matrix = data.corr()
print(matrix)
# Out:
#           SL        SW        PL        PW
# SL  1.000000 -0.109369  0.871754  0.817954
# SW -0.109369  1.000000 -0.420516 -0.356544
# PL  0.871754 -0.420516  1.000000  0.962757
# PW  0.817954 -0.356544  0.962757  1.000000
# <ipython-input-6-361bb74a0668>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matrix = data.corr()

# %%
sns.heatmap(matrix,cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# Petal width and Petal length have high correlations.
# Petal length and Sepal width have good correlations.
# Petal width and Sepal length have good correlations.

# %%
plt.scatter(data['SL'],data['SW'])
plt.title('Scatterplot of Sepal length vs Sepal width')
plt.xlabel('SL')
plt.ylabel('SW')
# Out:
# Text(0, 0.5, 'SW')

# %%
print('The value ranges of petal length, petal width, sepal length and sepal width of iris setosa ')
data[['PL','PW','SL','SW']].head(50).plot()
# Out:
# The value ranges of petal length, petal width, sepal length and sepal width of iris setosa
# <Axes: >
